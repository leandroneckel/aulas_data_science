# %%
import pandas as pd
dados = pd.read_csv('base_projeto02.csv')

# %%
dados
# Out:
#         gender   age  driving_license  region_code  previously_insured  \
# 0         Male  44.0              1.0         28.0                 NaN
# 1         Male  76.0              1.0          3.0                 0.0
# 2         Male  47.0              1.0         28.0                 0.0
# 3         Male  21.0              1.0         11.0                 1.0
# 4       Female  29.0              1.0         41.0                 1.0
# ...        ...   ...              ...          ...                 ...
# 381104    Male  74.0              1.0         26.0                 NaN
# 381105    xale  30.0              1.0         37.0                 1.0
# 381106    Male  21.0              1.0         30.0                 1.0
# 381107  Female  68.0              NaN         14.0                 0.0
# 381108     NaN   NaN              1.0         29.0                 0.0
#
#        vehicle_age vehicle_damage  annual_premium  policy_sales_channel  \
# ...

# %%
resultados = pd.DataFrame(columns = ['nome_modelo','f1_score','accuracy_score'])

# %%
resultados
# Out:
# Empty DataFrame
# Columns: [nome_modelo, f1_score, accuracy_score]
# Index: []

# %%
dados = dados.dropna()

# %%
dados = dados[dados['gender'].isin(['Male','Female'])]
dados
# Out:
#         gender   age  driving_license  region_code  previously_insured  \
# 1         Male  76.0              1.0          3.0                 0.0
# 2         Male  47.0              1.0         28.0                 0.0
# 3         Male  21.0              1.0         11.0                 1.0
# 4       Female  29.0              1.0         41.0                 1.0
# 5       Female  24.0              1.0         33.0                 0.0
# ...        ...   ...              ...          ...                 ...
# 381091    Male  71.0              1.0         28.0                 1.0
# 381092    Male  38.0              1.0         28.0                 1.0
# 381094  Female  47.0              1.0         20.0                 0.0
# 381100  Female  29.0              1.0         28.0                 0.0
# 381106    Male  21.0              1.0         30.0                 1.0
#
#        vehicle_age vehicle_damage  annual_premium  policy_sales_channel  \
# ...

# %%
dados = dados[dados.vehicle_age.isin(['1-2 Year','< 1 Year','> 2 Years'])]
dados
# Out:
#         gender   age  driving_license  region_code  previously_insured  \
# 1         Male  76.0              1.0          3.0                 0.0
# 2         Male  47.0              1.0         28.0                 0.0
# 3         Male  21.0              1.0         11.0                 1.0
# 4       Female  29.0              1.0         41.0                 1.0
# 5       Female  24.0              1.0         33.0                 0.0
# ...        ...   ...              ...          ...                 ...
# 381091    Male  71.0              1.0         28.0                 1.0
# 381092    Male  38.0              1.0         28.0                 1.0
# 381094  Female  47.0              1.0         20.0                 0.0
# 381100  Female  29.0              1.0         28.0                 0.0
# 381106    Male  21.0              1.0         30.0                 1.0
#
#        vehicle_age vehicle_damage  annual_premium  policy_sales_channel  \
# ...

# %%
dados = pd.get_dummies(dados,columns=['gender','vehicle_age'],dtype=int)
dados
# Out:
#          age  driving_license  region_code  previously_insured vehicle_damage  \
# 1       76.0              1.0          3.0                 0.0             No
# 2       47.0              1.0         28.0                 0.0            Yes
# 3       21.0              1.0         11.0                 1.0             No
# 4       29.0              1.0         41.0                 1.0             No
# 5       24.0              1.0         33.0                 0.0            Yes
# ...      ...              ...          ...                 ...            ...
# 381091  71.0              1.0         28.0                 1.0             No
# 381092  38.0              1.0         28.0                 1.0             No
# 381094  47.0              1.0         20.0                 0.0            Yes
# 381100  29.0              1.0         28.0                 0.0            Yes
# 381106  21.0              1.0         30.0                 1.0             No
#
# ...

# %%
import numpy as np
dados['vehicle_damage'] = np.where(dados['vehicle_damage']=='Yes',1,0)

# %%
dados
# Out:
#          age  driving_license  region_code  previously_insured  \
# 1       76.0              1.0          3.0                 0.0
# 2       47.0              1.0         28.0                 0.0
# 3       21.0              1.0         11.0                 1.0
# 4       29.0              1.0         41.0                 1.0
# 5       24.0              1.0         33.0                 0.0
# ...      ...              ...          ...                 ...
# 381091  71.0              1.0         28.0                 1.0
# 381092  38.0              1.0         28.0                 1.0
# 381094  47.0              1.0         20.0                 0.0
# 381100  29.0              1.0         28.0                 0.0
# 381106  21.0              1.0         30.0                 1.0
#
#         vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 1                    0         33536.0                  26.0    183.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dados_escalonados = pd.DataFrame(scaler.fit_transform(dados),columns=dados.columns)

# %%
dados_escalonados
# Out:
#              age  driving_license  region_code  previously_insured  \
# 0       0.861538              1.0     0.057692                 0.0
# 1       0.415385              1.0     0.538462                 0.0
# 2       0.015385              1.0     0.211538                 1.0
# 3       0.138462              1.0     0.788462                 1.0
# 4       0.061538              1.0     0.634615                 0.0
# ...          ...              ...          ...                 ...
# 185664  0.784615              1.0     0.538462                 1.0
# 185665  0.276923              1.0     0.538462                 1.0
# 185666  0.415385              1.0     0.384615                 0.0
# 185667  0.138462              1.0     0.538462                 0.0
# 185668  0.015385              1.0     0.576923                 1.0
#
#         vehicle_damage  annual_premium  policy_sales_channel   vintage  \
# 0                  0.0        0.057496              0.154321  0.598616
# ...

# %%
colunas = dados.columns.tolist()
colunas.remove('response')
colunas.append('response')
dados_escalonados = dados_escalonados[colunas]
dados_escalonados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185669 entries, 0 to 185668
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   age                    185669 non-null  float64
#  1   driving_license        185669 non-null  float64
#  2   region_code            185669 non-null  float64
#  3   previously_insured     185669 non-null  float64
#  4   vehicle_damage         185669 non-null  float64
#  5   annual_premium         185669 non-null  float64
#  6   policy_sales_channel   185669 non-null  float64
#  7   vintage                185669 non-null  float64
#  8   gender_Female          185669 non-null  float64
#  9   gender_Male            185669 non-null  float64
#  10  vehicle_age_1-2 Year   185669 non-null  float64
#  11  vehicle_age_< 1 Year   185669 non-null  float64
#  12  vehicle_age_> 2 Years  185669 non-null  float64
#  13  response               185669 non-null  float64
# ...

# %%
treino = dados_escalonados.sample(frac = 0.8)
teste = dados_escalonados.drop(index=treino.index)

# %%
treino.shape,teste.shape,dados_escalonados.shape
# Out:
# ((148535, 14), (37134, 14), (185669, 14))

# %%
x_treino = treino.iloc[:,:13].values
y_treino = treino.iloc[:,13].values
x_teste = teste.iloc[:,:13].values
y_teste = teste.iloc[:,13].values

# %%
x_treino
# Out:
# array([[0.30769231, 1.        , 0.78846154, ..., 1.        , 0.        ,
#         0.        ],
#        [0.27692308, 1.        , 0.53846154, ..., 1.        , 0.        ,
#         0.        ],
#        [0.52307692, 1.        , 0.53846154, ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.52307692, 1.        , 0.03846154, ..., 1.        , 0.        ,
#         0.        ],
#        [0.50769231, 1.        , 0.53846154, ..., 1.        , 0.        ,
#         0.        ],
#        [0.43076923, 1.        , 0.65384615, ..., 1.        , 0.        ,
#         0.        ]])

# %%
from sklearn.metrics import f1_score,accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
modelo = DecisionTreeClassifier()
modelo.fit(x_treino,y_treino)
y_pred = modelo.predict(x_teste)
f1 = f1_score(y_teste,y_pred)
acc = accuracy_score(y_teste,y_pred)
print(f"Esse modelo retornou F1 Score = {f1} e Accuracy Score = {acc}")
# Out:
# Esse modelo retornou F1 Score = 0.28760922202337086 e Accuracy Score = 0.8177680831582916

# %%
nome = input('Digite o nome do modelo: ')
add = [nome,f1,acc]
resultados.loc[resultados.shape[0]]=add
resultados
# Out:
#                                nome_modelo  f1_score  accuracy_score
# 0  modelo simples com processamento básico  0.287609        0.817768
