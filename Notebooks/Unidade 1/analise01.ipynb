# %% [markdown]
# ## Colunas
# 1. age
# 2. sex
# 3. chest pain type (4 values)
# 4. resting blood pressure
# 5. serum cholestoral in mg/dl
# 6. fasting blood sugar > 120 mg/dl
# 7. resting electrocardiographic results (values 0,1,2)
# 8. maximum heart rate achieved
# 9. exercise induced angina
# 10. oldpeak = ST depression induced by exercise relative to rest
# 11. the slope of the peak exercise ST segment
# 12. number of major vessels (0-3) colored by flourosopy
# 13. thal: 1 = normal; 2 = fixed defect; 3 = reversable defect (0 - no registry)

# %% [markdown]
# Abertura do DF

# %%
#importando dados
import pandas as pd
dados = pd.read_csv('heart.csv')

# %%
#retornando prévia dos dados
dados
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#descrição geral dos dados
dados.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
#calcular desvios e desvios quadráticos da idade
idade = dados[['age']]
idade_media = idade.age.mean() #calcula a média
idade['desvios_absolutos'] = abs(idade.age -idade_media)
# Out:
# C:\Users\necke\AppData\Local\Temp\ipykernel_8784\4042088895.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   idade['desvios_absolutos'] = abs(idade.age -idade_media)

# %%
idade
# Out:
#       age  desvios_absolutos
# 0      52           2.434146
# 1      53           1.434146
# 2      70          15.565854
# 3      61           6.565854
# 4      62           7.565854
# ...   ...                ...
# 1020   59           4.565854
# 1021   60           5.565854
# 1022   47           7.434146
# 1023   50           4.434146
# 1024   54           0.434146
#
# [1025 rows x 2 columns]

# %%
media_desvios_absolutos = idade.desvios_absolutos.mean()
media_desvios_absolutos
# Out:
# 7.443226650803093

# %%
idade['desvios_quadraticos'] = idade.desvios_absolutos**2
# Out:
# C:\Users\necke\AppData\Local\Temp\ipykernel_8784\4096182279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   idade['desvios_quadraticos'] = idade.desvios_absolutos**2

# %%
idade
# Out:
#       age  desvios_absolutos  desvios_quadraticos
# 0      52           2.434146             5.925068
# 1      53           1.434146             2.056776
# 2      70          15.565854           242.295800
# 3      61           6.565854            43.110434
# 4      62           7.565854            57.242142
# ...   ...                ...                  ...
# 1020   59           4.565854            20.847020
# 1021   60           5.565854            30.978727
# 1022   47           7.434146            55.266532
# 1023   50           4.434146            19.661654
# 1024   54           0.434146             0.188483
#
# [1025 rows x 3 columns]

# %%
media_desvios_quadraticos = idade.desvios_quadraticos.mean()
media_desvios_quadraticos
# Out:
# 82.22615110053539

# %%
# Coeficience de variação (o quanto o desvio padrão está para a média)
cv = dados.age.std()/dados.age.mean()*100
cv
# Out:
# 16.666542681378953

# %%
dados.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# ## Tarefa 01
#
# As colunas: age, trestbps, chol, thalach e olpeak não são categóricas ou binárias.
#
# Encontre a essas colunas, determine aquela que possui o menor CV. Faça isso preferencialmente de forma automática (via loop for, por exemplo)
#
# utilize: selecao_colunas = dados[['age','trestbps','chol','thalach','oldpeak']]
#
# para criar um dataframe separado somente com as colunas de interesse.

# %%
# Gráficos de histograma, boxplot e de densidade
import matplotlib.pyplot as plt

# %%
plt.hist(dados.chol)
# Out:
# (array([ 42., 247., 359., 231., 120.,  10.,  13.,   0.,   0.,   3.]),
#  array([126. , 169.8, 213.6, 257.4, 301.2, 345. , 388.8, 432.6, 476.4,
#         520.2, 564. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(dados.chol)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22c67700040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22c677005e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22c678eed30>],
#  'medians': [<matplotlib.lines.Line2D at 0x22c67700b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22c67700e50>],
#  'means': []}

# %%
from scipy.stats import gaussian_kde
densidade = gaussian_kde(dados.chol)
import numpy as np
x = np.linspace(dados.chol.min(),dados.chol.max(),dados.shape[0])
plt.plot(x,densidade(x))

# %%
#histograma e densidade combinados:
plt.hist(dados.chol,density=True)
plt.plot(x,densidade(x))

# %%
#Analisando graficamente se há diferença entre o chol entre os dois sexos:
dados
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
sex_0 = dados[dados.sex==0]
sex_1 = dados[dados.sex==1]

# %%
sex_0.chol.describe()
# Out:
# count    312.000000
# mean     261.455128
# std       64.466781
# min      141.000000
# 25%      215.000000
# 50%      254.000000
# 75%      302.000000
# max      564.000000
# Name: chol, dtype: float64

# %%
sex_1.chol.describe()
# Out:
# count    713.000000
# mean     239.237027
# std       43.155535
# min      126.000000
# 25%      208.000000
# 50%      234.000000
# 75%      269.000000
# max      353.000000
# Name: chol, dtype: float64

# %%
plt.hist(sex_0.chol,alpha = 0.8)
plt.hist(sex_1.chol,alpha = 0.8)
plt.legend(['sex_0','sex_1'])

# %% [markdown]
# Quando comparamos dois histogramas, é interessante que eles sejam montados por meio de densidas, cas contrário podemos ter dificuldade em fazer a visualização dos dados pelo fato de um dos histogramas absolutos possuírem mais dados que o outro

# %%
plt.hist(sex_0.chol,alpha = 0.8,density=True)
plt.hist(sex_1.chol,alpha = 0.8,density=True)
plt.legend(['sex_0','sex_1'])

# %% [markdown]
# ## Tarefa 02
#
# Verificar graficamente se há diferença da variável thalach entre grupos de faixas de idades diferentes

# %%
grupo_1 = dados[dados.age<51]
grupo_2 = dados[(dados.age>=51)&(dados.age<59)]
grupo_3 = dados[dados.age>=59]
grupo_1.shape,grupo_2.shape,grupo_3.shape
# Out:
# ((315, 14), (355, 14), (355, 14))

# %% [markdown]
# ## Analisando a variável Thal (categórica)

# %%
dados.thal
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       2
#        ..
# 1020    2
# 1021    3
# 1022    2
# 1023    2
# 1024    3
# Name: thal, Length: 1025, dtype: int64

# %%
plt.hist(dados.thal)
# Out:
# (array([  7.,   0.,   0.,  64.,   0.,   0., 544.,   0.,   0., 410.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
#Cálculo da moda
dados.thal.mode()
# Out:
# 0    2
# Name: thal, dtype: int64

# %%
#valor esperado: para calcular, precisamos transformar para valores não nulos
thal = dados[['thal']]
#filtrando para valores não nulos
thal = thal[thal.thal!=0]
plt.hist(thal.thal)
# Out:
# (array([ 64.,   0.,   0.,   0.,   0., 544.,   0.,   0.,   0., 410.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
#calculando as probabilidades de cada categoria e organizando em uma tabela
probs = thal.thal.value_counts(normalize=True)
df_probs = probs.to_frame()
df_probs.reset_index(inplace=True)
df_probs.columns = ['categoria', 'probabilidade']
df_probs
# Out:
#    categoria  probabilidade
# 0          2       0.534381
# 1          3       0.402750
# 2          1       0.062868

# %%
df_probs['momento'] = df_probs.categoria*df_probs.probabilidade
df_probs
# Out:
#    categoria  probabilidade   momento
# 0          2       0.534381  1.068762
# 1          3       0.402750  1.208251
# 2          1       0.062868  0.062868

# %%
valor_esperado = df_probs.momento.sum()
valor_esperado
# Out:
# 2.3398821218074657

# %% [markdown]
# ## Gráficos de barra de pizza

# %%
contagem = thal.thal.value_counts()
contagem
# Out:
# thal
# 2    544
# 3    410
# 1     64
# Name: count, dtype: int64

# %%
plt.bar(contagem.index,contagem.values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# thal: 1 = normal; 2 = fixed defect; 3 = reversable defect

# %%
mapa = {
    1:'Normal',
    2:'Fixed defect',
    3:'Reversable defect'
}
thal['nomes'] = thal.thal.map(mapa)

# %%
thal
# Out:
#       thal              nomes
# 0        3  Reversable defect
# 1        3  Reversable defect
# 2        3  Reversable defect
# 3        3  Reversable defect
# 4        2       Fixed defect
# ...    ...                ...
# 1020     2       Fixed defect
# 1021     3  Reversable defect
# 1022     2       Fixed defect
# 1023     2       Fixed defect
# 1024     3  Reversable defect
#
# [1018 rows x 2 columns]

# %%
contagem = thal.nomes.value_counts()
contagem
# Out:
# nomes
# Fixed defect         544
# Reversable defect    410
# Normal                64
# Name: count, dtype: int64

# %%
plt.bar(contagem.index,contagem.values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(contagem.index,contagem.values)
# Out:
# <BarContainer object of 3 artists>

# %%
nomes = contagem.index
valores = contagem.values
plt.pie(valores,labels = nomes,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c69bc00a0>,
# ...
#  [Text(-0.11858184251110336, 1.0935896609911198, 'Fixed defect'),
#   Text(-0.09831335402131561, -1.095597774925214, 'Reversable defect'),
#   Text(1.078614756104373, -0.21584764977618834, 'Normal')],
#  [Text(-0.06468100500605636, 0.5965034514497016, '53.4%'),
#   Text(-0.053625465829808504, -0.5975987863228439, '40.3%'),
#   Text(0.5883353215114762, -0.11773508169610272, '6.3%')])

# %% [markdown]
# ## Tarefa 3:
#
# Categorizar a coluna trestbps em 5 faixas de valores diferentes: até 120, entre 120 e 140, entre 140 e 160, entre 160 e 180 e acima de 180 e montar um gráfico de pizza mostrando a distribuição dessas 5 categorias. Pesquise no chatgpt por:  "em um dataframe pandas, como criar uma coluna categórica baseada em faixas de valores de uma coluna numérica?"

# %% [markdown]
# ## Correlação

# %%
dados
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
selecao = dados[['age','trestbps','chol','thalach','oldpeak']]
selecao
# Out:
#       age  trestbps  chol  thalach  oldpeak
# 0      52       125   212      168      1.0
# 1      53       140   203      155      3.1
# 2      70       145   174      125      2.6
# 3      61       148   203      161      0.0
# 4      62       138   294      106      1.9
# ...   ...       ...   ...      ...      ...
# 1020   59       140   221      164      0.0
# 1021   60       125   258      141      2.8
# 1022   47       110   275      118      1.0
# 1023   50       110   254      159      0.0
# 1024   54       120   188      113      1.4
#
# [1025 rows x 5 columns]

# %%
#Correlação entre duas colunas
corr = selecao.age.corr(selecao.trestbps)
corr
# Out:
# 0.2711214063160757

# %%
#matriz de correlação
correlacao = selecao.corr()
correlacao
# Out:
#                age  trestbps      chol   thalach   oldpeak
# age       1.000000  0.271121  0.219823 -0.390227  0.208137
# trestbps  0.271121  1.000000  0.127977 -0.039264  0.187434
# chol      0.219823  0.127977  1.000000 -0.021772  0.064880
# thalach  -0.390227 -0.039264 -0.021772  1.000000 -0.349796
# oldpeak   0.208137  0.187434  0.064880 -0.349796  1.000000

# %%
#mapa de calor das correlações
plt.imshow(correlacao,cmap='hot',interpolation=None)
plt.colorbar()
plt.xticks(range(len(correlacao)), correlacao.columns, rotation=20)
plt.yticks(range(len(correlacao)), correlacao.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x22c6ac01fa0>,
# ...
#  [Text(0, 0, 'age'),
#   Text(0, 1, 'trestbps'),
#   Text(0, 2, 'chol'),
#   Text(0, 3, 'thalach'),
#   Text(0, 4, 'oldpeak')])

# %%
#gráfico de dispersão
plt.scatter(selecao.age,selecao.thalach)
plt.xlabel('age')
plt.ylabel('thalach')
plt.grid(ls = ':')

# %% [markdown]
# # Explorando mais de duas variáveis

# %%
# Tabela de contingência
dados
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#contingência analizando a média de trestbps por sexo e por idade
cont = dados.groupby(by=['sex','age']).agg(
    media_trestbps = ('trestbps','mean')
)
cont
# Out:
#          media_trestbps
# sex age
# 0   34       118.000000
#     35       138.000000
#     37       120.000000
#     39       119.142857
#     41       118.250000
# ...                 ...
# 1   67       131.045455
#     68       147.333333
#     69       150.000000
#     70       146.285714
#     77       125.000000
#
# [73 rows x 1 columns]

# %%
cont.to_excel('analise_sexo_idade.xlsx')

# %%
# Gráfico de dispersão de idade contra trestbps ressaltanto com cores o chol
x = dados.age
y = dados.trestbps
cor = dados.chol
sc = plt.scatter(x, y, c=cor, cmap='viridis') 
plt.colorbar(sc, label='chol')
plt.xlabel('age')
plt.ylabel('trestpbs')
plt.grid(ls = ':')

# %%
tamanho = dados.thalach

tamanho_norm = (tamanho - tamanho.min()) / (tamanho.max() - tamanho.min())

# Definir um fator de escala
fator_escala = 500  # ajuste este valor conforme necessário

# Aplicar o fator de escala aos valores normalizados
tamanho = tamanho_norm * fator_escala

plt.figure(figsize=(10, 10))  
sc = plt.scatter(x, y, c=cor, s=tamanho, cmap='viridis', alpha=0.6) 
plt.colorbar(sc, label='chol')
plt.xlabel('age')
plt.ylabel('trestpbs')
plt.grid(ls = ':')

sizes_legend = [min(dados.thalach), np.max(dados.thalach)]
labels = [str(s) for s in sizes_legend]

legend_elements = [plt.Line2D([0], [0], marker='o', color='w', label=label,
                              markerfacecolor='gray', markersize=s/10) 
                   for label, s in zip(labels, sizes_legend)]
plt.legend(handles=legend_elements, title="thalach")

# %%
#grafico de contorno
from scipy.interpolate import griddata
xi = np.linspace(dados['age'].min(), dados['age'].max(), 100)
yi = np.linspace(dados['trestbps'].min(), dados['trestbps'].max(), 100)
xi, yi = np.meshgrid(xi, yi)
zi = griddata((dados['age'], dados['trestbps']), dados['chol'], (xi, yi), method='cubic')
plt.figure(figsize=(10, 10)) 
plt.contour(xi, yi, zi, levels=14, linewidths=0.5, colors='k')
plt.contourf(xi, yi, zi, levels=14, cmap=plt.cm.rainbow)
plt.colorbar(label='chol')
plt.grid(ls=':')
plt.xlabel('age')
plt.ylabel('trestpbs')
# Out:
# Text(0, 0.5, 'trestpbs')

# %%
#gráfico de violino
plt.violinplot(dados.trestbps,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x22c6b96c4f0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x22c6b96c3d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x22c6b96cbb0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x22c6b96cf70>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x22c6b97c370>}

# %%
dd = dados.copy()

# %%
import seaborn as sns
dd['sex'] = dd.sex.astype('category')
plt.figure(figsize=(10,6))
sns.violinplot(x='sex', y='trestbps', data=dados)
plt.title('Gráfico de Violino para trestbps por sex')
plt.xlabel('sex')
plt.ylabel('trestbps')
# Out:
# Text(0, 0.5, 'trestbps')

# %%
import seaborn as sns
dd['age'] = dd.age.astype('category')
plt.figure(figsize=(15,6))
sns.violinplot(x='age', y='trestbps', data=dados)
plt.title('Gráfico de Violino para trestbps por age')
plt.xlabel('age')
plt.ylabel('trestbps')
# Out:
# Text(0, 0.5, 'trestbps')

# %% [markdown]
# ## Tarefa 4
#
# Definir faixas 4 faixas etárias distintas (até 40 anos, de 40 a 50, de 50 a 60 e maior que 60 anos). Para cada faixa etária, também definir conjuntos de dados para cada sexo. Fazer um gráfico de barras agrupado de forma que a variável chol seja explorada por faixa de idade e por idade.
#
# Exemplo:
#
# ![image.png](attachment:image.png)
